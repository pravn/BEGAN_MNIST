# %%
import numpy
import torch
import torch.utils.data
from torchvision import datasets, transforms

# %%
# %load_ext autoreload
# %autoreload 2

# %%
class Params:
    def __init__(self):
        self.batch_size = 32
        self.num_batches = -1
        self.num_samples = -1
        self.n_z = 300
        self.dim_h = 50
        self.sigma = 1
        self.lambda_k = 0.001
        self.gamma = 0.8
        self.lr = 1e-4
        self.n_channel = 1
        self.x_size = 28
        self.y_size = 28
        self.img_size = 28 # == x_size == y_size
params = Params()

# %%
train_loader = torch.utils.data.DataLoader(
    datasets.MNIST('../data', train=True, download=True,
                   transform=transforms.ToTensor()),
    batch_size=params.batch_size, shuffle=True)
params.num_batches = len(train_loader)
params.num_samples = params.num_batches * params.batch_size

# %%
print('size', len(train_loader))
# Out:
# size 1875

# %%
# %aimport began
from began import return_model
decoder, disc = return_model(params)
# Out:
# return model - decoder.cuda(), disc.cuda()

# %%
#print(vae)

# %%
#print(disc)

# %%
# %aimport train_began
from train_began import run_trainer

# %%
run_trainer(train_loader, disc, decoder, params)
# Out:
# saving images
# Epoch, G_loss, D_loss, convergence_metric 1 678.4771405011415 272.3504985310137 0.23376506567001343
# saving images
# Epoch, G_loss, D_loss, convergence_metric 2 475.28243848402053 96.32610898278654 0.05760747194290161
# saving images
# Epoch, G_loss, D_loss, convergence_metric 3 5.608818849228555 57.58390869386494 0.047763608396053314
# saving images
# Epoch, G_loss, D_loss, convergence_metric 4 0.567905239367974 46.61751478537917 0.03972084820270538
# saving images
# Epoch, G_loss, D_loss, convergence_metric 5 0.13217371365681174 41.28946868889034 0.037955235689878464
# saving images
# Epoch, G_loss, D_loss, convergence_metric 6 0.04859304877027171 38.01052852720022 0.03441879525780678
# saving images
# Epoch, G_loss, D_loss, convergence_metric 7 1104.8756767138602 -136.2077803099528 0.537658154964447
# saving images
# Epoch, G_loss, D_loss, convergence_metric 8 338.71560990065336 30.20645744074136 0.0231953002512455
# saving images
# ...
